# %%
from PIL import Image
from imgtools import *

# %%
dir = 'C:/Users/ADMIN/Documents/src_cv/img/01/1.jpg'

# %%
img = load_image(dir)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1919x953>

# %%
#định vị khu vuwc cắt
region = (100,75,175,175)
#cắt vùng ảnh
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=75x100>

# %%
#dán
#xác định vị trí
paste_position = (20,150)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1919x953>
