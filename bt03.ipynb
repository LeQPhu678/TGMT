# %%
#!pip install pillow

# %%
# dấu # ghi chú
#shift + enter: run đoạn code cà thêm một dòng mới
#ctrl + enter: run đoạn code

# %%
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
#khai báo một thư mục (/ hoặc \\)
dir = 'C:/Users/ADMIN/Documents/src_cv/img/01/1.jpg'

# %%
#khai báo đường dẫn ảnh
img = load_image(dir)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1919x953>

# %%
# Kích thước ban đầu:
print(img.size)
# Out:
# (1919, 953)

# %%
# Thay đổi kích thước
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Task: lưu ảnh
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x1000>

# %%
# Thay đổi kích thước
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Task: lưu ảnh
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=50x25>
