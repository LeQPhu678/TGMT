# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
# Đường dẫn ảnh
dir = 'C:/Users/ADMIN/Documents/src_cv/img/01/2.jpg'

# %%
# Đọc ảnh 
img = load_image(dir)

# Resize
# img = img.resize((250,250))

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=151x225>

# %%
# Chuyển từ ảnh RGB sang ảnh xám
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=151x225>

# %%
# Phân RGB thành 3 tầng màu khác nhau
red_band, green_band, blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=151x225>
# <PIL.Image.Image image mode=L size=151x225>
# <PIL.Image.Image image mode=L size=151x225>

# %%
# Trộn ảnh
merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=151x225>

# %%
# Trộn ảnh
merged_image =  Image.merge("RGB", (blue_band,red_band, green_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=151x225>
