# %%
#!pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Đường dẫn ảnh
dir = 'C:/Users/ADMIN/Documents/src_cv/img/01/2.jpg'
# Đọc ảnh và hiển thị
im = Image.open(dir)
# display(im)
plt.imshow(im)

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y)
plt.show()

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='red')
plt.show()

# %%
# Tắt hệ trục tọa độ
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]

plt.plot(x, y, color='red')  # Thay đổi màu thành đỏ
plt.title('Biểu đồ ví dụ với màu đỏ', color='green')  # Thêm tiêu đề
# Tắt hệ trục tọa độ
plt.axis('off')  # Tắt hệ trục tọa độ
plt.show()

# %%
# Vẽ trên hình ảnh
# ĐỌc ảnh
im = Image.open(dir)
x = [100, 100, 400, 400]
y = [200, 300, 200, 300]

plt.imshow(im) # Hiển thị hình ảnh
plt.plot(x,y, 'ro--') 
plt.show()
